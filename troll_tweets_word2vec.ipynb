# %%
# !pip install --upgrade gensim
# Out:
# ...
#      |████████████████████████████████| 24.7MB 274kB/s  eta 0:00:01   |███████                         | 5.5MB 2.1MB/s eta 0:00:10     |█████████████▍                  | 10.3MB 1.7MB/s eta 0:00:09     |███████████████████▉            | 15.3MB 4.1MB/s eta 0:00:03     |█████████████████████▋          | 16.7MB 4.1MB/s eta 0:00:02
# ...
#      |████████████████████████████████| 71kB 5.3MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 1.4MB 2.0MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 133kB 3.9MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.6MB 1.3MB/s eta 0:00:01     |███████████████████             | 3.3MB 885kB/s eta 0:00:03
# ...
#      |████████████████████████████████| 71kB 1.6MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 552kB 326kB/s eta 0:00:01    |███                             | 51kB 4.4MB/s eta 0:00:01
# ...
#   Stored in directory: /Users/computer/Library/Caches/pip/wheels/ab/10/93/5cff86f5b721d77edaecc29959b1c60d894be1f66d91407d28
# ...

# %%
import pandas as pd
import numpy as np

# %%
csv = 'clean_tweet.csv'
my_df = pd.read_csv(csv,index_col=0)
my_df.head()
# Out:
#                                                 text account_type
# 0  we have sitting democrat us senator on trial f...        Right
# 1  marshawn lynch arrives to game in anti trump s...        Right
# 2  daughter of fallen navy sailor delivers powerf...        Right
# 3  just in president trump dedicates presidents c...        Right
# 4   respecting our national anthem standforouranthem        Right

# %%
my_df1 = my_df['text']
my_df1.head()
# Out:
# 0    we have sitting democrat us senator on trial f...
# 1    marshawn lynch arrives to game in anti trump s...
# 2    daughter of fallen navy sailor delivers powerf...
# 3    just in president trump dedicates presidents c...
# 4     respecting our national anthem standforouranthem
# Name: text, dtype: object

# %%
df2 = my_df.apply(lambda x: ','.join(x.astype(str)))

# %%
# # Create an empty list 
# Row_list =[] 
  
# # Iterate over each row 
# for index, rows in my_df.iterrows(): 
#     # Create list for the current row 
#     my_list =[rows.text] 
      
#     # append the list to the final list 
#     Row_list.append(my_list) 
  
# # Print the list 
# print(Row_list) 
df2.head()
# Out:
# text            we have sitting democrat us senator on trial f...
# account_type    Right,Right,Right,Right,Right,Right,Right,Righ...
# dtype: object

# %%
# from gensim import models
# from gensim.models import Word2Vec, KeyedVectors
# model = Word2Vec(my_df1, min_count=1,size= 50,workers=3, window =3, sg = 1)

# %%
df_clean = pd.DataFrame({'clean': df2})

# %%
sent = [row.split(',') for row in df_clean['clean']]

# %%
sent[:2]
# Out:
# [['we have sitting democrat us senator on trial for corruption and you ve barely heard peep from the mainstream media',
#   'marshawn lynch arrives to game in anti trump shirt judging by his sagging pants the shirt should say lynch vs belt',
#   'daughter of fallen navy sailor delivers powerful monologue on anthem protests burns her nfl packers gear boycottnfl',
#   'just in president trump dedicates presidents cup golf tournament trophy to the people of florida texas and puerto rico',
#   'respecting our national anthem standforouranthem',
#   'dan bongino nobody trolls liberals better than donald trump exactly',
#   'nan',
#   'does not matter that cnn does not report on your crimes this will not change the fact that you re going down',
#   'as much as hate promoting cnn article here they are admitting everything trump said about pr relief two days ago',
#   'after the genocide remark from san juan mayor the narrative has changed though fixes it reporting constantly',
# ...

# %%
model = Word2Vec(sent, min_count=1,size= 50,workers=3, window =3, sg = 1)

# %%
model["trump"]
# Out:
# /Users/computer/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-0.00837332,  0.00541278,  0.00157557, -0.0091758 ,  0.00137798,
#         0.00428574,  0.00761803,  0.00264118,  0.00051898,  0.00455358,
#        -0.00699454,  0.00127638, -0.00916803,  0.00462535,  0.00080661,
#        -0.00184091,  0.0099017 ,  0.00489394, -0.00661524, -0.00084872,
#         0.00241282,  0.00024123, -0.00351838, -0.00879401, -0.0095163 ,
#        -0.0094726 , -0.00721337,  0.00461454,  0.00039259,  0.00054046,
#        -0.00569251,  0.00460501, -0.00683217,  0.00598696, -0.00778767,
#         0.00115319, -0.00243512, -0.00593933, -0.00772818,  0.00144577,
#        -0.00844862,  0.00815829, -0.00458397, -0.00142125,  0.00524774,
#        -0.00178357,  0.00241401,  0.00420676, -0.00432759,  0.00038699],
# ...

# %%
model.wv.similarity('trump', 'Left')
# Out:
# 0.07449175

# %%
sim_words = model.wv.most_similar('trump')

# %%
print(sim_words)
# Out:
# [('itturnedawkwardwhen you kinda hungry but he kinda fuhrer', 0.5818239450454712), ('send your kid to college support the surveillance state', 0.5784330368041992), ('sextingwentwrongwhen was featured on criminal minds', 0.5763497352600098), ('hillary did not say ny was bombed she said so bombed zombiehillary', 0.5640810132026672), ('exomars', 0.5628669857978821), ('president obama shortens the sentences of drug offenders', 0.5589914321899414), ('pnm latest rate increase request draws ire from customers', 0.5573521852493286), ('trump planned embassy move to jerusalem backed by israeli officials', 0.5474933385848999), ('we re going to do things your way from now on thingseveryboywantstohear disaster', 0.5441226959228516), ('member of the twitter illuminati obamanextjob', 0.5429083704948425)]
